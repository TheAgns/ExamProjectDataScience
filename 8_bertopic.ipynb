# %% [markdown]
# ## TrustPilot reviews

# %% [markdown]
# We'll be performing some topic classification using TrustPilot reviews.

# %%
import requests
from bs4 import BeautifulSoup

def get_reviews(url):
    texts = []
    ratings = []
    
    for page in range(1, 101):
 
        response = requests.get(f"{url}?page={page}")
        soup = BeautifulSoup(response.content, "html.parser")

        review_divs = soup.find_all("div", {"class": "styles_cardWrapper__LcCPA styles_show__HUXRb styles_reviewCard__9HxJJ"})

        for div in review_divs:
            review_title = div.find("h2", {"class": "review-title"})
            review_stars_div = div.find("div", {"class": "styles_reviewHeader__iU9Px"})

            review_rating = review_stars_div['data-service-review-rating']

            review_paragraph = div.find("p")
            texts.append(review_paragraph.text)
            ratings.append(review_rating)

    reviews = dict(zip(texts, ratings))
    return reviews

# %%
from string import punctuation

import dacy
import nltk
import pandas as pd
import spacy
from bertopic import BERTopic
from bertopic.vectorizers import ClassTfidfTransformer
from sentence_transformers import SentenceTransformer
from sklearn.feature_extraction.text import CountVectorizer

# %%
url = 'https://dk.trustpilot.com/review/www.postnord.dk'

# %%
reviews_dict = json_or_fetch(url, fetch.trustpilot, 'data/trustpilot.json')

# %%
reviews_dict = get_reviews(url)

# %%
reviews = []
for company_reviews in reviews_dict.values():
    reviews.extend(company_reviews)

# %%
docs2 = get_reviews('https://dk.trustpilot.com/review/www.fedex.com')

# %%
docs3 = get_reviews('https://dk.trustpilot.com/review/www.ups.com')

# %%
reviews_dict.update(docs2)
reviews_dict.update(docs3)

# %%
df = pd.DataFrame(reviews)
df.head()
# Out:
#                                               review
# 0  Nær box kunne ikke åbne. fik at vide de ville ...
# 1  Jeg bliver nødt til at tage omdelt post med i ...
# 2  Altid godt at få leveret fra post nord. Men I ...
# 3  Kan det være rigtigt, at man i 2023 ikke kan g...
# 4  Jeg forstår ikke helt, at når der ikke er plad...

# %%
# number of columns and rows
print("Number of columns:", len(df.columns))
print("Number of rows:", len(df))

# %%
# type of data
print("Data types:")
print(df.dtypes)

# %%
# see the size
df.shape

# %%
df.columns

# %%
df = pd.DataFrame(reviews_dict.items(), columns=['review', 'rating'])

# %%
df['rating'] = df['rating'].astype(int)

# %%
df.groupby('rating').count()
# Out:
#         review
# rating
# 1         1322
# 2           96
# 3           61
# 4          115
# 5          844

# %%
docs = list(reviews_dict.keys())

# %%
docs2 = list(get_reviews('https://dk.trustpilot.com/review/www.fedex.com').keys())

# %%
docs.extend(docs2)

# %%
docs3 = list(get_reviews('https://dk.trustpilot.com/review/www.ups.com').keys())
docs.extend(docs3)

# %%
docs[-1:-10:-1]
# Out:
# ['Jeg har flere gange fået leveret varer med UPS, og det er alle gange gået uden problemer ;) super service og hurtig levering.',
#  'Har fået leveret pakker hos dem flere gange... jeg kan ikke huske noget negativt - så det må være godt',
#  'Leveringen fejlede ingenting, men håber aldrig nogen får brug for at komme i kontakt med UPS kundeservice.\rFor at gøre en lang historie kort: En medarbejder hos UPS udfylder en fragtseddel for mig forkert selvom jeg 3 gange understregede, at det var en modtager-betaler-pakke. \rJeg får derfor tilsendt en regning samt en masse rykkere selvom jeg er i løbende kontakt med deres kundeservice, hvor de lover at de vil krediterer mig, og at de vil lukke sagen med det samme. \r- Imens de "undersøger" sagen sætter de den ikke i bero, hvilket betyder, at jeg får flere rykkere fra inkasso.\r- Det er ligeledes ikke muligt at kontakte de personer, der undersøger sagen eller få respons på, hvad der sker og evt, hvor lang tid det vil tage. \r- De tager MEGET lang tid om at undersøge.\r- De kan ikke finde ud af at kontakte modtager\r- De undskylder ikke på noget tidspunkt deres fejl.\r- Deres kundeservice kommer med forskellige og modsigende udmeldinger.\r Efter 6 mdr tovtrækkeri konkluderer de, at jeg bare skal betale. Jeg er meget forundret, da de selv har lavet fejlen, og deres kundeservice gang på gang har sagt at de nok skulle krediterer mig, og at jeg ikke skulle tænke mere på det. \rEfter et opkald til modtageren fra min side er sagen løst.',
#  'Nu har man taget fri fra arbejdet for at kunne modtage en pakke i deres "lille" tids vindue fra 9 - 17 .. til MIN store overraskelse ser jeg på Deres hjemmeside at de har "forsøgt" at levere pakken... HVORHENNE det var da ikke på min adresse da..',
#  'Jeg har flere gange skulle benytte deres service ifm. reperation af en bærbar. \r Første gang de afhenter den har chaufføren ikke den korrekte afhentningsemballage med på trods af, dette blev gjort klart under afhentningsrekvireringen. \r Anden gang jeg gør brug af deres service levere de en bærbar retur ved at stille den i en åben carport (som har et utæt tag) lige inden for åbningen i den danske vinter. Dette resultere i den får fugt og skal retur til reparation. \rDe skal så afhente den igen, så der kan laves en skadesanmeldelse.\rTrods fortælling om de skal afhente på en ny adresse kører de til den gamle og prøver at afhente. Der blev tilmed lovet der ville blive ringet til mig for at aftale nærmere om afhentning. Dette skete heller ikke.\r Det skal dog siges til deres forsvar at der ikke var problemer med at klage over chaufføren.\r De har nu forsøgt at afhente flere gange. ALLE gange på forkert adresse selvom det er sagt 3 gange til dem at det er en anden adresse. Dette er tydeligvis ikke gået op for dem endnu',
#  "Bestilte produkter fra apple US, og fik at vide at den ville blive leveret i dk inden for 3-4 dage, dog skulle jeg ikke blive overrasket hvis den var der inden for 2 dage.. Rigtig nok havde UPS været der 2 dage efter bestilling men var desværre ikke hjemme, der ligger så en seddel i postkassen uden nogen anden info end et track'n'trace nummer som man ikke kan bruge til en skid når man ved de allerede har prøvet at levere pakken.. Det er nu 6 dage siden de har været her første gang og har ringet og rykket efter min pakke 3 gange hvor de siger at den skulle være i en bil på vej ud, men har intet set til pakken, så nu har jeg ikke andet at gøre end at sidde og vente til den kommer, og kundeservice kan ikke hjælpe en skid andet end at sige man skal have tolmodighed !\rKræftedme værre end Post Danmark der i det mindste kan levere selvom der kommer lidt sne ! Vil anbefale Apple og alle andre virksomheder at anvende alle andre end UPS !",
#  'Jeg skulle have en pakke sendt fra England til Danmark. Pakken forsvinder dog ud i det blå mens den er i deres varetægt. Jeg kontakter UPS 5 gange og får hver gang beskeden "Vi ihværksætter en eftersøgning af pakken". Til sidst opgiver jeg at få pakken og beder om erstatning. UPS påstår dog at jeg ikke har medkøbt forsikring for forsendelsen samt at jeg ikke har opgivet korrekt værdi på forsendelsen. Løgn, latin og dårlige undskyldninger. \r Under hele episoden oplevede vi uforskammede og ligeglade kundeservice medarbejdere som ikke virkede interesserede i at løse problemet. F.eks. skulle en navngiven medarbejder ringe mig op mens jeg var på arbejde. Medarbejderen vidste at jeg var på arbejde, og vi havde aftalt at hvis jeg ikke tog den ville han prøve igen i løbet af dagen. UPS ringer kun fra hemmeligt nummer, så jeg havde ikke selv mulighed for selv at ringe ham op og jeg måtte ikke få hans nummer.. Han ringer til mig en enkelt gang den aftalte dag, hvor jeg desværre havde en kunde og ikke kunne besvare opkaldet. Da jeg endelig selv får fat i ham en uges tid senere påstår han at han forsøgte at ringe op adskillige gange. Der var dog kun et enkelt ubesvaret opkald på min telefon.. Da jeg konfrontere ham med hans løgn smider han røret på.. Simpelthen barnligt.. Hvordan kan sådan en virksomhed overhovedet overleve..',
#  'UPS har leveret over 200 forsendelser til mig, og ikke en eneste har været forsinket, og har en fin kundeservice. Men det er dog desværre afsindigt dyrt at sende fra Danmark vha. UPS.',
#  'Har ikke brugt dem før, men prøvede for første gang i sidste uge. Fik leveret en vare fra Caliroots. Fint fint. Det eneste jeg er lidt bitter over er, at de skriver de har været her, selvom jeg var hjemme HELE dagen.\r "THE RECEIVER WAS UNAVAILABLE TO SIGN ON THE 1ST DELIVERY ATTEMPT. A 2ND DELIVERY ATTEMPT WILL BE MADE  KOLDING, DK"\r Så 3/5 fordi det var en fredag jeg skulle have haft dem .. sørgeligt.']

# %% [markdown]
# I'm having trouble with stopwords even though I'm using the techniques described in the Bertopic documentation for revoming those. It's not recommended to remove them in preprocessing, but I thought I'd try and see if it helped.

# %%
# da_stopwords = nltk.corpus.stopwords.words('danish')
da_stopwords = spacy.lang.da.stop_words.STOP_WORDS

# %%
type(da_stopwords)
# Out:
# set

# %%
count_vectorizer = CountVectorizer(stop_words=list(da_stopwords))

# %%
def clean_sentence(sentence):
    sentence = sentence.strip()
    words = nltk.word_tokenize(sentence, language='danish')
    words = [word for word in words if word.lower() not in da_stopwords and word not in punctuation]
    return ' '.join(words)

# %%
docs = [clean_sentence(doc) for doc in docs]

# %%
embedder = SentenceTransformer('paraphrase-multilingual-MiniLM-L12-v2')

# %%
embeddings = embedder.encode(docs, show_progress_bar=True)
# Out:
# Batches:   0%|          | 0/77 [00:00<?, ?it/s]

# %%
embeddings.shape

# %% [markdown]
# ## Dacy embeddings

# %%
# nlp = dacy.load('medium', exclude=['tagger', 'parser', 'ner', 'attribute_ruler', 'lemmatizer'])

# %%
# dacy_docs = list(nlp.pipe(docs))

# %% [markdown]
# ## Bertopic model

# %%
ctfid_model = ClassTfidfTransformer(reduce_frequent_words=True)

# %%
topic_model = BERTopic(language="multilingual", nr_topics=None, min_topic_size=5, vectorizer_model=count_vectorizer,
                       seed_topic_list=[['god', 'godt', 'hurtig', 'hurtigt'],
                                        ['dårlig', 'dårligt', 'dårlige', 'langsom']])

# %%
topics, probs = topic_model.fit_transform(docs, embeddings)

# %%
topic_model.get_topic_info()[:20]
# Out:
#     Topic  Count                                     Name
# 0      -1    933               -1_pakken_ups_pakke_hjemme
# 1       0    125        0_hurtig_levering_tilfreds_præcis
# 2       1     88                     1_kl_fredag_april_21
# 3       2     80                  2_hjemme_hele_dagen_fkn
# 4       3     76      3_dårlig_kundeservice_firma_service
# 5       4     71                 4_fedex_pakke_pakken_usa
# 6       5     67              5_post_nord_postnord_hurtig
# 7       6     55        6_tyskland_pakken_oktober_kolding
# 8       7     47         7_bestilte_lørdag_hurtig_bestilt
# 9       8     43               8_postnord_pakke_fik_retur
# 10      9     35        9_komme_kontakt_umuligt_telefonen
# 11     10     32           10_ok_perfekt_orden_sædvanligt
# 12     11     28  11_hurtig_levering_problemer_afhentning
# 13     12     27        12_tyskland_ups_kontakter_danmark
# 14     13     27          13_ups_virksomheder_aktion_2011
# 15     14     27         14_hurtigt_effektivt_hurtig_kvik
# 16     15     26          15_døren_dejligt_hurtig_behøver
# 17     16     25         16_ødelagt_kassen_stykker_pallen
# 18     17     25             17_stjerne_stjerner_give_sgu
# 19     18     24         18_hjemme_ups_gange_kundeservice

# %% [markdown]
# ~~At least, now the name isn't all stopwords, but it still only puts it in one outlier topic.~~
#
# I think the actual problem is just having way too few documents for it extract topics.
#
# Decreasing `min_topic_size` helped.

# %%
topic_model.visualize_barchart()

# %% [markdown]
# The topics don't seem to allign greatly with sentiment just from looking at the keywords.

# %%
topic_model.visualize_topics(top_n_topics=20)

# %%
topic_model.visualize_documents(docs, embeddings=embeddings, hide_annotations=True)
